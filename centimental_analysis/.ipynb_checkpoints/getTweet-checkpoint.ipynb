# %%
from openpyxl import load_workbook

# Excelファイルのロード(読み取り専用)
excel_path='../archive_wiki/D18/D18-2018.7.24.xlsx'
workbook = load_workbook(filename=excel_path, read_only=True)

# Excelのシート名一覧を表示
#print(workbook.sheetnames)
sheet=workbook[workbook.sheetnames[1]]
sent_dic=[]
for row in sheet[f'A2:A{sheet.max_row}']:
    for cell in row:
        sent_dic.append(cell.value)
    
# ロードしたExcelファイルを閉じる
print(sent_dic[:5])
workbook.close()
sent_dic=list(filter(lambda sent:sent is not None,sent_dic))
#感性語辞典のエクセルの感性語と,その感情データ3人分を合体させて保存
# Out:
# ['哀', '愛', '相いれない', '哀感', '愛敬']

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.1.0-py2.py3-none-any.whl (62 kB)
# Collecting requests-oauthlib<2,>=1.0.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3,>=2.11.1 in c:\users\jikan\anaconda3\lib\site-packages (from tweepy) (2.24.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jikan\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jikan\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jikan\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jikan\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2020.6.20)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.1 requests-oauthlib-1.3.0 tweepy-4.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
query=sent_dic[0]
for word in sent_dic[1:]:
    query = query+" OR "+word
print(query)
# Out:
# 哀 OR 愛 OR 相いれない OR 哀感 OR 愛敬 OR 愛好 OR 哀愁 OR 愛執 OR 哀傷 OR 愛情 OR 愛する OR 哀惜 OR 哀切 OR 愛想を尽かす OR 愛着 OR 哀悼 OR 愛慕 OR 愛欲 OR 愛らしい OR 青息吐息 OR 仰ぐ OR 青筋を立てる OR 赤恥 OR 赤らむ OR 赤らめる OR 崇める OR 飽き飽き OR 飽き足りる OR 諦め OR 諦める OR 飽きる OR 呆れ返る OR 呆れ果てる OR 呆れる OR 悪感情 OR 倦む OR 憧れ OR 憧れる OR 浅ましい OR 嘲る OR 味気ない OR 焦り OR 焦る OR 唖然 OR 頭に来る OR 頭を悩ませる OR 当たり散らす OR あッ OR あっけない OR 呆気に取られる OR 圧迫感 OR 熱い OR 熱いものがこみ上げる OR 厚かましい OR 熱くなる OR 暑苦しい OR 後味が良くない OR 後味が宜しくない OR 後味が悪い OR 侮る OR 阿鼻叫喚 OR 危ない OR あほらしい OR 荒々しい OR あらッ OR ありがたい OR ありがたみ OR ありがた迷惑 OR ありがと OR ありがとう OR ありゃ OR 慌てふためく OR 慌てる OR 哀れ OR 憐れ OR 憐れみ OR 憐れむ OR 安逸 OR 暗鬱 OR 安閑 OR 案外 OR 安心 OR 案ずる OR 暗然 OR 安息感 OR 暗澹 OR 安定 OR 安堵 OR 安寧 OR 安楽 OR 怡怡 OR 言い寄る OR いかがわしい OR 厳つい OR 怒らす OR 怒り OR 怒りが爆発する OR 怒り狂う OR 遺憾 OR 意外 OR 啀み合う OR 啀む OR 息を詰める OR 息が詰まる OR 息苦しい OR 息苦しさ OR 意気軒昂 OR 意気消沈 OR 憤り OR 憤る OR 行き悩む OR 生き恥 OR 息巻く OR 熱り立つ OR 息を飲む OR 息を潜める OR いけ好かない OR いけ図々しい OR 依怙地になる OR 遺恨 OR 勇ましい OR 意趣 OR 萎縮 OR 意地汚い OR 意地悪 OR いそいそ OR 意想外 OR 痛い OR 痛々しい OR 居た堪れない OR 痛ましい OR 痛み OR 痛み入る OR 悼む OR 痛める OR いちゃもんを付ける OR 一憂 OR 一喜 OR 一驚 OR 慈しみ OR 慈しむ OR 逸楽 OR 厭う OR 愛おしい OR 愛おしむ OR 愛し
# %%
class TweetsGetter(object):
    __metaclass__ = ABCMeta

    def __init__(self):
        self.session = OAuth1Session(CK, CS, AT, AS)

    @abstractmethod
    def specifyUrlAndParams(self, keyword):
        '''
        呼出し先 URL、パラメータを返す
        '''

    @abstractmethod
    def pickupTweet(self, res_text, includeRetweet):
        '''
        res_text からツイートを取り出し、配列にセットして返却
        '''

    @abstractmethod
    def getLimitContext(self, res_text):
        '''
        回数制限の情報を取得 （起動時）
        '''

    def collect(self, total = -1, onlyText = False, includeRetweet = False):
        '''
        ツイート取得を開始する
        '''

        #----------------
        # 回数制限を確認
        #----------------
        self.checkLimit()

        #----------------
        # URL、パラメータ
        #----------------
        url, params = self.specifyUrlAndParams()
        params['include_rts'] = str(includeRetweet).lower()
        # include_rts は statuses/user_timeline のパラメータ。search/tweets には無効

        #----------------
        # ツイート取得
        #----------------
        cnt = 0
        unavailableCnt = 0
        while True:
            res = self.session.get(url, params = params)
            if res.status_code == 503:
                # 503 : Service Unavailable
                if unavailableCnt > 10:
                    raise Exception('Twitter API error %d' % res.status_code)

                unavailableCnt += 1
                print ('Service Unavailable 503')
                self.waitUntilReset(time.mktime(datetime.datetime.now().timetuple()) + 30)
                continue

            unavailableCnt = 0

            if res.status_code != 200:
                raise Exception('Twitter API error %d' % res.status_code)

            tweets = self.pickupTweet(json.loads(res.text))
            if len(tweets) == 0:
                # len(tweets) != params['count'] としたいが
                # count は最大値らしいので判定に使えない。
                # ⇒  "== 0" にする
                # https://dev.twitter.com/discussions/7513
                break

            for tweet in tweets:
                if (('retweeted_status' in tweet) and (includeRetweet is False)):
                    pass
                else:
                    if onlyText is True:
                        yield tweet['text']
                    else:
                        yield tweet

                    cnt += 1
                    if cnt % 100 == 0:
                        print ('%d件 ' % cnt)

                    if total > 0 and cnt >= total:
                        return

            params['max_id'] = tweet['id'] - 1

            # ヘッダ確認 （回数制限）
            # X-Rate-Limit-Remaining が入ってないことが稀にあるのでチェック
            if ('X-Rate-Limit-Remaining' in res.headers and 'X-Rate-Limit-Reset' in res.headers):
                if (int(res.headers['X-Rate-Limit-Remaining']) == 0):
                    self.waitUntilReset(int(res.headers['X-Rate-Limit-Reset']))
                    self.checkLimit()
            else:
                print ('not found  -  X-Rate-Limit-Remaining or X-Rate-Limit-Reset')
                self.checkLimit()

    def checkLimit(self):
        '''
        回数制限を問合せ、アクセス可能になるまで wait する
        '''
        unavailableCnt = 0
        while True:
            url = "https://api.twitter.com/1.1/application/rate_limit_status.json"
            res = self.session.get(url)

            if res.status_code == 503:
                # 503 : Service Unavailable
                if unavailableCnt > 10:
                    raise Exception('Twitter API error %d' % res.status_code)

                unavailableCnt += 1
                print ('Service Unavailable 503')
                self.waitUntilReset(time.mktime(datetime.datetime.now().timetuple()) + 30)
                continue

            unavailableCnt = 0

            if res.status_code != 200:
                raise Exception('Twitter API error %d' % res.status_code)

            remaining, reset = self.getLimitContext(json.loads(res.text))
            if (remaining == 0):
                self.waitUntilReset(reset)
            else:
                break

    def waitUntilReset(self, reset):
        '''
        reset 時刻まで sleep
        '''
        seconds = reset - time.mktime(datetime.datetime.now().timetuple())
        seconds = max(seconds, 0)
        print ('\n     =====================')
        print ('     == waiting %d sec ==' % seconds)
        print ('     =====================')
        sys.stdout.flush()
        time.sleep(seconds + 10)  # 念のため + 10 秒

    @staticmethod
    def bySearch(keyword):
        return TweetsGetterBySearch(keyword)

    @staticmethod
    def byUser(screen_name):
        return TweetsGetterByUser(screen_name)



class TweetsGetterBySearch(TweetsGetter):
    '''
    キーワードでツイートを検索
    '''
    def __init__(self, keyword):
        super(TweetsGetterBySearch, self).__init__()
        self.keyword = keyword

    def specifyUrlAndParams(self):
        '''
        呼出し先 URL、パラメータを返す
        '''
        url = 'https://api.twitter.com/1.1/search/tweets.json'
        params = {'q':self.keyword, 'count':100}
        return url, params

    def pickupTweet(self, res_text):
        '''
        res_text からツイートを取り出し、配列にセットして返却
        '''
        results = []
        for tweet in res_text['statuses']:
            results.append(tweet)

        return results

    def getLimitContext(self, res_text):
        '''
        回数制限の情報を取得 （起動時）
        '''
        remaining = res_text['resources']['search']['/search/tweets']['remaining']
        reset     = res_text['resources']['search']['/search/tweets']['reset']

        return int(remaining), int(reset)


class TweetsGetterByUser(TweetsGetter):
    '''
    ユーザーを指定してツイートを取得
    '''
    def __init__(self, screen_name):
        super(TweetsGetterByUser, self).__init__()
        self.screen_name = screen_name

    def specifyUrlAndParams(self):
        '''
        呼出し先 URL、パラメータを返す
        '''
        url = 'https://api.twitter.com/1.1/statuses/user_timeline.json'
        params = {'screen_name':self.screen_name, 'count':200}
        return url, params

    def pickupTweet(self, res_text):
        '''
        res_text からツイートを取り出し、配列にセットして返却
        '''
        results = []
        for tweet in res_text:
            results.append(tweet)

        return results

    def getLimitContext(self, res_text):
        '''
        回数制限の情報を取得 （起動時）
        '''
        remaining = res_text['resources']['statuses']['/statuses/user_timeline']['remaining']
        reset     = res_text['resources']['statuses']['/statuses/user_timeline']['reset']

        return int(remaining), int(reset)


if __name__ == '__main__':

    # キーワードで取得
    for word in sent_dic:
        query=word
        for word in sent_dic[sent_dic.index(word)+1:]:
            if 1000<len(query):
                break
            query = query+" OR "+word
        getter = TweetsGetter.bySearch(query)

        # ユーザーを指定して取得 （screen_name）
        #getter = TweetsGetter.byUser('@realDonaldTrump')

        list_text = []

        for tweet in getter.collect(total = 10):
            list_text.append(tweet['text'])
        with open("Tweetdata_utf-16.csv", "w", newline="", encoding="utf-16") as f:
            writer = csv.writer(f, dialect="excel-tab", quoting=csv.QUOTE_ALL)
            writer.writerows(list_text)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-51-2ca705e7bbeb> in <module>
#     238         list_text = []
#     239
# --> 240         for tweet in getter.collect(total = 10):
#     241             list_text.append(tweet['text'])
#     242         with open("Tweetdata_utf-16.csv", "w", newline="", encoding="utf-16") as f:
#
# <ipython-input-51-2ca705e7bbeb> in collect(self, total, onlyText, includeRetweet)
#      60
#      61             if res.status_code != 200:
# ---> 62                 raise Exception('Twitter API error %d' % res.status_code)
#      63
#      64             tweets = self.pickupTweet(json.loads(res.text))
#
# Exception: Twitter API error 403

# %%
df = pd.DataFrame(columns=['text'])
df_new = df.assign(text=list_text)

print(df_new[0:5])
# Out:
#                                                 text
# 0  Get quality grades in:\n#Onlineclass\n#Homewor...
# 1  🎯ما نقدمه في #البرمجة😌\n#MachineLearning\n#Art...
# 2                      @Among_Natsu Pythonで組むパターンだ…！
# 3  We ensure #A+ in your 👔 🌒 \n #EssayHelp\n #Dat...
# 4  Check under that table if there's a python lyi...

# %%
dir(query)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']
